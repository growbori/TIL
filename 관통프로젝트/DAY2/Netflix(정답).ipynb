# %%
# 패키지 import
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# CSV 파일 경로
csv_path = "NFLX.csv"

# CSV 파일 읽어오기 (첫 번째, 마지막 열 제외)
df = pd.read_csv(csv_path, usecols=range(0, 5))

# DataFrame 출력
df
# Out:
#             Date        Open        High         Low       Close
# 0     2018-02-05  262.000000  267.899994  250.029999  254.259995
# 1     2018-02-06  247.699997  266.700012  245.000000  265.720001
# 2     2018-02-07  266.579987  272.450012  264.329987  264.559998
# 3     2018-02-08  267.079987  267.619995  250.000000  250.100006
# 4     2018-02-09  253.850006  255.800003  236.110001  249.470001
# ...          ...         ...         ...         ...         ...
# 1004  2022-01-31  401.970001  427.700012  398.200012  427.140015
# 1005  2022-02-01  432.959991  458.480011  425.540009  457.130005
# 1006  2022-02-02  448.250000  451.980011  426.480011  429.480011
# 1007  2022-02-03  421.440002  429.260010  404.279999  405.600006
# 1008  2022-02-04  407.309998  412.769989  396.640015  410.170013
#
# [1009 rows x 5 columns]

# %%
df['Date'] = pd.to_datetime(df['Date'])

# %%
df.dtypes
# Out:
# Date     datetime64[ns]
# Open            float64
# High            float64
# Low             float64
# Close           float64
# dtype: object

# %%
# 2021년 이후 데이터 필터링
df_after_2021 = df[df["Date"] >= "2021-01-01"]

# 출력하기
df_after_2021
# Out:
#            Date        Open        High         Low       Close
# 733  2021-01-04  539.000000  540.799988  515.090027  522.859985
# 734  2021-01-05  521.549988  526.780029  515.890015  520.799988
# 735  2021-01-06  511.970001  513.099976  499.500000  500.489990
# 736  2021-01-07  508.279999  516.440002  506.420013  508.890015
# 737  2021-01-08  511.309998  513.239990  504.510010  510.399994
# ...         ...         ...         ...         ...         ...
# 1004 2022-01-31  401.970001  427.700012  398.200012  427.140015
# 1005 2022-02-01  432.959991  458.480011  425.540009  457.130005
# 1006 2022-02-02  448.250000  451.980011  426.480011  429.480011
# 1007 2022-02-03  421.440002  429.260010  404.279999  405.600006
# 1008 2022-02-04  407.309998  412.769989  396.640015  410.170013
#
# [276 rows x 5 columns]

# %%
# 그래프 그리기
plt.plot(df_after_2021['Date'], df_after_2021['Close'], label='Close')


# 그래프 제목 설정
plt.title('NFLX Close Price')

# x축 레이블 설정
plt.xlabel('Date')

# y축 레이블 설정
plt.ylabel('Close Price')

# 범례 표시
plt.legend()

# 그래프 표시
plt.show()

# %%
# 2022년 이후 데이터 필터링
df_after_2021 = df[df["Date"] >= "2021-01-01"]

df_after_2021_max = df_after_2021.Close.max()
df_after_2021_min = df_after_2021.Close.min()
# 출력하기
print('최고 종가: ', df_after_2021_max)
print('최저 종가: ', df_after_2021_min)
# Out:
# 최고 종가:  691.690002
# 최저 종가:  359.700012

# %%
print(df_after_2021.dtypes)
# Out:
# Date     datetime64[ns]
# Open            float64
# High            float64
# Low             float64
# Close           float64
# dtype: object

# %%
df_after_2021
# Out:
#            Date        Open        High         Low       Close
# 733  2021-01-04  539.000000  540.799988  515.090027  522.859985
# 734  2021-01-05  521.549988  526.780029  515.890015  520.799988
# 735  2021-01-06  511.970001  513.099976  499.500000  500.489990
# 736  2021-01-07  508.279999  516.440002  506.420013  508.890015
# 737  2021-01-08  511.309998  513.239990  504.510010  510.399994
# ...         ...         ...         ...         ...         ...
# 1004 2022-01-31  401.970001  427.700012  398.200012  427.140015
# 1005 2022-02-01  432.959991  458.480011  425.540009  457.130005
# 1006 2022-02-02  448.250000  451.980011  426.480011  429.480011
# 1007 2022-02-03  421.440002  429.260010  404.279999  405.600006
# 1008 2022-02-04  407.309998  412.769989  396.640015  410.170013
#
# [276 rows x 5 columns]

# %%
df_after_2021['Date_month'] = df_after_2021['Date'].dt.strftime('%y-%m')
df_after_2021
# Out:
# C:\Users\SSAFY\AppData\Local\Temp\ipykernel_17748\2512290624.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_after_2021['Date_month'] = df_after_2021['Date'].dt.strftime('%y-%m')
#            Date        Open        High         Low       Close Date_month
# 733  2021-01-04  539.000000  540.799988  515.090027  522.859985      21-01
# 734  2021-01-05  521.549988  526.780029  515.890015  520.799988      21-01
# 735  2021-01-06  511.970001  513.099976  499.500000  500.489990      21-01
# 736  2021-01-07  508.279999  516.440002  506.420013  508.890015      21-01
# 737  2021-01-08  511.309998  513.239990  504.510010  510.399994      21-01
# ...         ...         ...         ...         ...         ...        ...
# 1004 2022-01-31  401.970001  427.700012  398.200012  427.140015      22-01
# 1005 2022-02-01  432.959991  458.480011  425.540009  457.130005      22-02
# 1006 2022-02-02  448.250000  451.980011  426.480011  429.480011      22-02
# 1007 2022-02-03  421.440002  429.260010  404.279999  405.600006      22-02
# 1008 2022-02-04  407.309998  412.769989  396.640015  410.170013      22-02
#
# [276 rows x 6 columns]

# %%
df1 = df_after_2021.groupby('Date_month').mean()

df1
# Out:
#                                     Date        Open        High         Low  \
# Date_month
# 21-01      2021-01-16 10:06:18.947368448  530.531051  537.838944  519.854214
# 21-02      2021-02-13 10:06:18.947368448  547.777366  555.494205  540.621576
# 21-03      2021-03-15 15:39:07.826086912  519.429134  527.057390  511.326090
# 21-04      2021-04-16 17:08:34.285714176  532.810952  537.802858  527.041430
# 21-05      2021-05-15 12:00:00.000000000  496.923996  502.062502  491.996503
# 21-06      2021-06-15 07:38:10.909090816  503.470914  508.116364  498.675455
# 21-07      2021-07-16 13:42:51.428571392  528.609045  534.298567  522.618091
# 21-08      2021-08-15 22:54:32.727272704  529.884541  535.937267  526.222275
# 21-09      2021-09-16 03:25:42.857142784  589.405233  598.170003  583.384760
# 21-10      2021-10-15 18:17:08.571428608  639.220474  648.829043  632.430001
# 21-11      2021-11-14 11:25:42.857142784  671.363334  677.726188  660.947617
# 21-12      2021-12-16 00:00:00.000000000  611.568640  616.962727  601.954548
# 22-01      2022-01-16 04:48:00.000000000  492.055000  498.946999  478.276000
# 22-02      2022-02-02 12:00:00.000000000  427.489998  438.122505  413.235008
#
#                  Close
# Date_month
# 21-01       526.816845
# 21-02       548.959999
# 21-03       518.123482
# 21-04       533.136662
# 21-05       496.714497
# 21-06       503.324091
# 21-07       528.653330
# 21-08       532.346817
# 21-09       590.795239
# 21-10       642.202849
# 21-11       667.524286
# 21-12       608.484089
# 22-01       487.853500
# 22-02       425.595009

# %%
# 그래프 그리기
plt.plot( df1['Close'])


# 그래프 제목 설정
plt.title('Monthly Average Close Price')

# x축 레이블 설정
plt.xlabel('Date')

# y축 레이블 설정
plt.ylabel('Average Close Price')

# x 축 설정(회전시키기)
plt.xticks(rotation=45)

# 범례 표시
plt.legend()

# 그래프 표시
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
# CSV 파일 경로
csv_path = "NFLX.csv"

# CSV 파일 읽어오기 (첫 번째, 마지막 열 제외)
df = pd.read_csv(csv_path, usecols=range(0, 5))

# 2022년 이후 데이터 필터링
df = df[df["Date"] >= "2022-01-01"]

# 수정된 데이터프레임 출력
df.head()
# Out:
#            Date        Open        High         Low       Close
# 985  2022-01-03  605.609985  609.989990  590.559998  597.369995
# 986  2022-01-04  599.909973  600.409973  581.599976  591.150024
# 987  2022-01-05  592.000000  592.840027  566.880005  567.520020
# 988  2022-01-06  554.340027  563.359985  542.010010  553.289978
# 989  2022-01-07  549.460022  553.429993  538.219971  541.059998

# %%
# 그래프 그리기
plt.plot(df['Date'], df['Low'], label='Low')
plt.plot(df['Date'], df['High'], label='High')
plt.plot(df['Date'], df['Close'], label='Close')

# 그래프 제목 설정
plt.title('High, Low, and Close Prices since january 2022')
          
# x축 레이블 설정
plt.xlabel('Date')

# y축 레이블 설정
plt.ylabel('Price')

# x 축 설정(회전시키기)
plt.xticks(rotation=45)

# 범례 표시
plt.legend()

# 그래프 표시
plt.show()
