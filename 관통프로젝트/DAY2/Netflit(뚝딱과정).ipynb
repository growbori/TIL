# %%
# 패키지 import
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# Out:
# C:\Users\SSAFY\AppData\Local\Temp\ipykernel_2264\3305069133.py:3: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
# CSV 파일 경로
csv_path = "NFLX.csv"

# CSV 파일 읽어오기 (첫 번째, 마지막 열 제외)
df = pd.read_csv(csv_path, usecols=range(0, 5))

# DataFrame 출력
df
# Out:
#             Date        Open        High         Low       Close
# 0     2018-02-05  262.000000  267.899994  250.029999  254.259995
# 1     2018-02-06  247.699997  266.700012  245.000000  265.720001
# 2     2018-02-07  266.579987  272.450012  264.329987  264.559998
# 3     2018-02-08  267.079987  267.619995  250.000000  250.100006
# 4     2018-02-09  253.850006  255.800003  236.110001  249.470001
# ...          ...         ...         ...         ...         ...
# 1004  2022-01-31  401.970001  427.700012  398.200012  427.140015
# 1005  2022-02-01  432.959991  458.480011  425.540009  457.130005
# 1006  2022-02-02  448.250000  451.980011  426.480011  429.480011
# 1007  2022-02-03  421.440002  429.260010  404.279999  405.600006
# 1008  2022-02-04  407.309998  412.769989  396.640015  410.170013
#
# [1009 rows x 5 columns]

# %%
df['Date'] = pd.to_datetime(df['Date'])

# %%
df.dtypes
# Out:
# Date     datetime64[ns]
# Open            float64
# High            float64
# Low             float64
# Close           float64
# dtype: object

# %%
# 2021년 이후 데이터 필터링
df_after_2021 = df[df["Date"] >= "2021-01-01"]

# 출력하기
df_after_2021
# Out:
#            Date        Open        High         Low       Close
# 733  2021-01-04  539.000000  540.799988  515.090027  522.859985
# 734  2021-01-05  521.549988  526.780029  515.890015  520.799988
# 735  2021-01-06  511.970001  513.099976  499.500000  500.489990
# 736  2021-01-07  508.279999  516.440002  506.420013  508.890015
# 737  2021-01-08  511.309998  513.239990  504.510010  510.399994
# ...         ...         ...         ...         ...         ...
# 1004 2022-01-31  401.970001  427.700012  398.200012  427.140015
# 1005 2022-02-01  432.959991  458.480011  425.540009  457.130005
# 1006 2022-02-02  448.250000  451.980011  426.480011  429.480011
# 1007 2022-02-03  421.440002  429.260010  404.279999  405.600006
# 1008 2022-02-04  407.309998  412.769989  396.640015  410.170013
#
# [276 rows x 5 columns]

# %%
# 그래프 그리기
plt.plot(df_after_2021['Date'], df_after_2021['Close'], label='Close')


# 그래프 제목 설정
plt.title('NFLX Close Price')

# x축 레이블 설정
plt.xlabel('Date')

# y축 레이블 설정
plt.ylabel('Close Price')

# 범례 표시
plt.legend()

# 그래프 표시
plt.show()

# %%
# 2022년 이후 데이터 필터링
df_after_2021 = df[df["Date"] >= "2021-01-01"]

df_after_2021_max = df_after_2021.Close.max()
df_after_2021_min = df_after_2021.Close.min()
# 출력하기
print('최고 종가: ', df_after_2021_max)
print('최저 종가: ', df_after_2021_min)
# Out:
# 최고 종가:  691.690002
# 최저 종가:  359.700012

# %%
print(df_after_2021.dtypes)
# Out:
# Date     datetime64[ns]
# Open            float64
# High            float64
# Low             float64
# Close           float64
# dtype: object

# %%
df_after_2021
# Out:
#            Date        Open        High         Low       Close
# 733  2021-01-04  539.000000  540.799988  515.090027  522.859985
# 734  2021-01-05  521.549988  526.780029  515.890015  520.799988
# 735  2021-01-06  511.970001  513.099976  499.500000  500.489990
# 736  2021-01-07  508.279999  516.440002  506.420013  508.890015
# 737  2021-01-08  511.309998  513.239990  504.510010  510.399994
# ...         ...         ...         ...         ...         ...
# 1004 2022-01-31  401.970001  427.700012  398.200012  427.140015
# 1005 2022-02-01  432.959991  458.480011  425.540009  457.130005
# 1006 2022-02-02  448.250000  451.980011  426.480011  429.480011
# 1007 2022-02-03  421.440002  429.260010  404.279999  405.600006
# 1008 2022-02-04  407.309998  412.769989  396.640015  410.170013
#
# [276 rows x 5 columns]

# %%
df_after_2021['Date_month'] = df_after_2021['Date'].dt.strftime('%y-%m')
df_after_2021
# Out:
# C:\Users\SSAFY\AppData\Local\Temp\ipykernel_2264\2512290624.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_after_2021['Date_month'] = df_after_2021['Date'].dt.strftime('%y-%m')
#            Date        Open        High         Low       Close Date_month
# 733  2021-01-04  539.000000  540.799988  515.090027  522.859985      21-01
# 734  2021-01-05  521.549988  526.780029  515.890015  520.799988      21-01
# 735  2021-01-06  511.970001  513.099976  499.500000  500.489990      21-01
# 736  2021-01-07  508.279999  516.440002  506.420013  508.890015      21-01
# 737  2021-01-08  511.309998  513.239990  504.510010  510.399994      21-01
# ...         ...         ...         ...         ...         ...        ...
# ...

# %%
df_after_2021.groupby('Date_month').mean()

df_after_2021
# Out:
#            Date        Open        High         Low       Close Date_month
# 733  2021-01-04  539.000000  540.799988  515.090027  522.859985      21-01
# 734  2021-01-05  521.549988  526.780029  515.890015  520.799988      21-01
# 735  2021-01-06  511.970001  513.099976  499.500000  500.489990      21-01
# 736  2021-01-07  508.279999  516.440002  506.420013  508.890015      21-01
# 737  2021-01-08  511.309998  513.239990  504.510010  510.399994      21-01
# ...         ...         ...         ...         ...         ...        ...
# 1004 2022-01-31  401.970001  427.700012  398.200012  427.140015      22-01
# 1005 2022-02-01  432.959991  458.480011  425.540009  457.130005      22-02
# 1006 2022-02-02  448.250000  451.980011  426.480011  429.480011      22-02
# 1007 2022-02-03  421.440002  429.260010  404.279999  405.600006      22-02
# 1008 2022-02-04  407.309998  412.769989  396.640015  410.170013      22-02
#
# [276 rows x 6 columns]

# %%
# 그래프 그리기
plt.plot(price_month['Date_month'], price_month['Close'], label='Close')


# 그래프 제목 설정
plt.title('Monthly Average Close Price')

# x축 레이블 설정
plt.xlabel('Date')

# y축 레이블 설정
plt.ylabel('Average Close Price')

# x 축 설정(회전시키기)
plt.xticks(rotation=45)

# 범례 표시
plt.legend()

# 그래프 표시
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 2
#       1 # 그래프 그리기
# ----> 2 plt.plot(price_month['Date_month'], price_month['Close'], label='Close')
#       5 # 그래프 제목 설정
#       6 plt.title('Monthly Average Close Price')
#
# NameError: name 'price_month' is not defined

# %%
start_date = df_after_2021['Date'].astype(str).iloc[0]
end_date = df_after_2021['Date'].astype(str).iloc[-1]

date_all = pd.date_range(start_date, end_date, freq='D').to_frame().rename(columns = {0:'Date'}).reset_index(drop=True)

month_end = pd.date_range(start_date, end_date, freq = 'ME')

# %%
month_end
# Out:
# DatetimeIndex(['2021-01-31', '2021-02-28', '2021-03-31', '2021-04-30',
#                '2021-05-31', '2021-06-30', '2021-07-31', '2021-08-31',
#                '2021-09-30', '2021-10-31', '2021-11-30', '2021-12-31',
#                '2022-01-31'],
#               dtype='datetime64[ns]', freq='ME')

# %%
price_month = df_after_2021[df_after_2021['Date'].isin(month_end)].reset_index(drop=True)

# %%
price_month
# Out:
#         Date        Open        High         Low       Close Date_month
# 0 2021-03-31  515.669983  528.130005  515.440002  521.659973      21-03
# 1 2021-04-30  505.000000  514.549988  505.000000  513.469971      21-04
# 2 2021-06-30  534.059998  534.380005  526.820007  528.210022      21-06
# 3 2021-08-31  566.119995  569.479980  561.609985  569.190002      21-08
# 4 2021-09-30  608.049988  619.000000  608.049988  610.340027      21-09
# 5 2021-11-30  668.200012  675.380005  640.010010  641.900024      21-11
# 6 2021-12-31  610.010010  614.080017  602.049988  602.440002      21-12
# 7 2022-01-31  401.970001  427.700012  398.200012  427.140015      22-01

# %%
# 그래프 그리기
plt.plot(price_month['Date'], price_month['Close'], label='Close')


# 그래프 제목 설정
plt.title('Monthly Average Close Price')

# x축 레이블 설정
plt.xlabel('Date')

# y축 레이블 설정
plt.ylabel('Average Close Price')

# x 축 설정(회전시키기)
plt.xticks(rotation=45)

# 범례 표시
plt.legend()

# 그래프 표시
plt.show()

# %%
# CSV 파일 경로
csv_path = "NFLX.csv"

# CSV 파일 읽어오기 (첫 번째, 마지막 열 제외)
df = pd.read_csv(csv_path, usecols=range(0, 5))

# 2022년 이후 데이터 필터링
df = df[df_after_2021["Date"] >= "2022-01-01"]

# 수정된 데이터프레임 출력
df.head()
# Out:
# C:\Users\SSAFY\AppData\Local\Temp\ipykernel_2264\381823347.py:8: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df = df[df_after_2021["Date"] >= "2022-01-01"]
# ---------------------------------------------------------------------------
# IndexingError                             Traceback (most recent call last)
# Cell In[21], line 8
#       5 df = pd.read_csv(csv_path, usecols=range(0, 5))
#       7 # 2022년 이후 데이터 필터링
# ----> 8 df = df[df_after_2021["Date"] >= "2022-01-01"]
#      10 # 수정된 데이터프레임 출력
#      11 df.head()
#
# File c:\Users\SSAFY\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\frame.py:4081, in DataFrame.__getitem__(self, key)
#    4079 # Do we have a (boolean) 1d indexer?
#    4080 if com.is_bool_indexer(key):
# -> 4081     return self._getitem_bool_array(key)
#    4083 # We are left with two options: a single key, and a collection of keys,
#    4084 # We interpret tuples as collections only for non-MultiIndex
# ...

# %%
# 그래프 그리기
plt.plot(df['Date'], df['Low'], label='Low')
plt.plot(df['Date'], df['High'], label='High')
plt.plot(df['Date'], df['Close'], label='Close')

# 그래프 제목 설정
plt.title('High, Low, and Close Prices since january 2022')
          
# x축 레이블 설정
plt.xlabel('Date')

# y축 레이블 설정
plt.ylabel('Price')

# x 축 설정(회전시키기)
plt.xticks(rotation=45)

# 범례 표시
plt.legend()

# 그래프 표시
plt.show()
